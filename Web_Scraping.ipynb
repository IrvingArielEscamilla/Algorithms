# %% [markdown]
# WEB SCRAPING

# %%
from urllib.request import urlopen
urlink = "https://es.wikipedia.org/wiki/NLTK"

# %%
web_page = urlopen(urlink)

# %%
web_page

# %%
html_bytes = web_page.read()
html = html_bytes.decode("utf-8")

# %%
print(html)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="es" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>NLTK - Wikipedia, la enciclopedia libre</title>
# ...
